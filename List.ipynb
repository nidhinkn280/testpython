# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhinkn280/testpython/blob/master/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits=["apple","orange","banana"]
print(fruits)
# Out:
# ['apple', 'orange', 'banana']

# %%
print(type(fruits))
# Out:
# <class 'list'>

# %%
print(len(fruits))
# Out:
# 3

# %%
print(fruits[0])
# Out:
# apple

# %%
print(fruits[2])
# Out:
# banana

# %%
print(fruits[-1])
# Out:
# banana

# %%
data=["nidhin",20,40.5,True]
print(data)
# Out:
# ['nidhin', 20, 40.5, True]

# %%
fruits=["apple","orange","banana","mango","pineapple"]
print(fruits[3:])
# Out:
# ['mango', 'pineapple']

# %%
fruits=["apple","orange","banana","mango","pineapple"]
newfruits=fruits[::-1]
print(newfruits)
# Out:
# ['pineapple', 'mango', 'banana', 'orange', 'apple']

# %%
fruits[0]="cherry"
print(fruits)
# Out:
# ['cherry', 'orange', 'banana', 'mango', 'pineapple']

# %%
fruits.append("papaya")
print(fruits)
# Out:
# ['cherry', 'orange', 'banana', 'mango', 'pineapple', 'papaya']

# %%
fruits.insert(1,"kiwi")
print(fruits)
# Out:
# ['cherry', 'kiwi', 'orange', 'banana', 'mango', 'pineapple', 'papaya']

# %%
fruit1=['cherry', 'kiwi', 'orange']
fruit2=['banana', 'mango', 'pineapple']
fruit1.extend(fruit2)
print(fruit1)
# Out:
# ['cherry', 'kiwi', 'orange', 'banana', 'mango', 'pineapple']

# %%
fruit2.extend(fruit1)
print(fruit2)
# Out:
# ['banana', 'mango', 'pineapple', 'cherry', 'kiwi', 'orange', 'banana', 'mango', 'pineapple']
