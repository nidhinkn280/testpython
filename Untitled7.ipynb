# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhinkn280/testpython/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first_name=input("enter your first name:")

last_name=input("enter your last name:")
print(first_name,last_name)
# Out:
# enter your first name:nidhin
# enter your last name:kumar
# nidhin kumar

# %%
fruits=["apple","mango","orange","banana"]
print(fruits[0])
print(fruits[-1])
# Out:
# apple
# banana

# %%
fruits.insert(2,"kiwi")
print(fruits)
# Out:
# ['apple', 'mango', 'kiwi', 'orange', 'banana']

# %%
fruits.reverse()
print(fruits)
# Out:
# ['banana', 'orange', 'kiwi', 'mango', 'apple']

# %%
print(fruits[1:4])
# Out:
# ['orange', 'kiwi', 'mango']

# %%
del fruits
