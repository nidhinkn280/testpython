# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhinkn280/testpython/blob/master/dictinory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dictionary
student={
    "name":"Nidhin",
    "Score":90,
    "subject":"Computer",
    "age":20
}
print(len(student))
print(type(student))
# Out:
# 4
# <class 'dict'>

# %%
student.update({"country":"India"})
print(student)
# Out:
# {'name': 'Nidhin', 'Score': 90, 'subject': 'Computer', 'age': 20, 'country': 'India'}

# %%
student["phone no"] = "xyz"
print(student)
# Out:
# {'name': 'Nidhin', 'Score': 90, 'subject': 'Computer', 'age': 20, 'country': 'India', 'phone no': 'xyz'}

# %%
for values in student.values():
  print(values)
# Out:
# Nidhin
# 90
# Computer
# 20
# India
# xyz

# %%
for key,values in student.items():
  print(key,values)
# Out:
# name Nidhin
# Score 90
# subject Computer
# age 20
# country India
# phone no xyz
