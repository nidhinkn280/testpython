# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhinkn280/testpython/blob/master/set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student={"nidhin","jhon","alice","jhon"}
print(type(student))
print(len(student))
student.add("nik") #add
student.update(["james","robert","raj"])#update
student.discard("james")#discard
student.remove("raj")#remove
print(student)
# Out:
# <class 'set'>
# 3
# {'alice', 'jhon', 'nidhin', 'robert', 'nik'}

# %%
student.clear()
print(student)
# Out:
# set()
